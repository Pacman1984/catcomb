# %%
from sklearn.datasets import fetch_openml
from sklearn.pipeline import Pipeline
from __init__ import ColumnsConcatenation

# %%
X, y = fetch_openml("titanic", version=1, as_frame=True, return_X_y=True)

# %%
pipe = Pipeline([("generate_columns", ColumnsConcatenation(columns='auto', level=2, max_cardinality=500))])
test = pipe.fit_transform(X)

# %%
test
# Out:
#       pclass                                             name     sex  \
# 0        1.0                    Allen, Miss. Elisabeth Walton  female
# 1        1.0                   Allison, Master. Hudson Trevor    male
# 2        1.0                     Allison, Miss. Helen Loraine  female
# 3        1.0             Allison, Mr. Hudson Joshua Creighton    male
# 4        1.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304     3.0                             Zabour, Miss. Hileni  female
# 1305     3.0                            Zabour, Miss. Thamine  female
# 1306     3.0                        Zakarian, Mr. Mapriededer    male
# 1307     3.0                              Zakarian, Mr. Ortin    male
# 1308     3.0                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  ...  \
# 0     29.0000    0.0    0.0   24160  211.3375       B5        S  ...
# 1      0.9167    1.0    2.0  113781  151.5500  C22 C26        S  ...
# 2      2.0000    1.0    2.0  113781  151.5500  C22 C26        S  ...
# 3     30.0000    1.0    2.0  113781  151.5500  C22 C26        S  ...
# 4     25.0000    1.0    2.0  113781  151.5500  C22 C26        S  ...
# ...       ...    ...    ...     ...       ...      ...      ...  ...
# 1304  14.5000    1.0    0.0    2665   14.4542     None        C  ...
# 1305      NaN    1.0    0.0    2665   14.4542     None        C  ...
# 1306  26.5000    0.0    0.0    2656    7.2250     None        C  ...
# 1307  27.0000    0.0    0.0    2670    7.2250     None        C  ...
# 1308  29.0000    0.0    0.0  315082    7.8750     None        S  ...
#
#            sex_cabin  sex_embarked     sex_boat  \
# 0          female_B5      female_S     female_2
# 1       male_C22 C26        male_S      male_11
# 2     female_C22 C26      female_S  female_None
# 3       male_C22 C26        male_S    male_None
# 4     female_C22 C26      female_S  female_None
# ...              ...           ...          ...
# 1304     female_None      female_C  female_None
# 1305     female_None      female_C  female_None
# 1306       male_None        male_C    male_None
# 1307       male_None        male_C    male_None
# 1308       male_None        male_S    male_None
#
#                                sex_home.dest cabin_embarked    cabin_boat  \
# 0                        female_St Louis, MO           B5_S          B5_2
# 1       male_Montreal, PQ / Chesterville, ON      C22 C26_S    C22 C26_11
# 2     female_Montreal, PQ / Chesterville, ON      C22 C26_S  C22 C26_None
# 3       male_Montreal, PQ / Chesterville, ON      C22 C26_S  C22 C26_None
# 4     female_Montreal, PQ / Chesterville, ON      C22 C26_S  C22 C26_None
# ...                                      ...            ...           ...
# 1304                             female_None            NaN           NaN
# 1305                             female_None            NaN           NaN
# 1306                               male_None            NaN           NaN
# 1307                               male_None            NaN           NaN
# 1308                               male_None            NaN           NaN
#
#                               cabin_home.dest embarked_boat  \
# 0                             B5_St Louis, MO           S_2
# 1     C22 C26_Montreal, PQ / Chesterville, ON          S_11
# 2     C22 C26_Montreal, PQ / Chesterville, ON        S_None
# 3     C22 C26_Montreal, PQ / Chesterville, ON        S_None
# 4     C22 C26_Montreal, PQ / Chesterville, ON        S_None
# ...                                       ...           ...
# 1304                                      NaN        C_None
# 1305                                      NaN        C_None
# 1306                                      NaN        C_None
# 1307                                      NaN        C_None
# 1308                                      NaN        S_None
#
#                      embarked_home.dest                      boat_home.dest
# 0                        S_St Louis, MO                      2_St Louis, MO
# 1     S_Montreal, PQ / Chesterville, ON  11_Montreal, PQ / Chesterville, ON
# 2     S_Montreal, PQ / Chesterville, ON                                 NaN
# 3     S_Montreal, PQ / Chesterville, ON                                 NaN
# 4     S_Montreal, PQ / Chesterville, ON                                 NaN
# ...                                 ...                                 ...
# 1304                             C_None                                 NaN
# 1305                             C_None                                 NaN
# 1306                             C_None                                 NaN
# 1307                             C_None                                 NaN
# 1308                             S_None                                 NaN
#
# [1309 rows x 23 columns]
